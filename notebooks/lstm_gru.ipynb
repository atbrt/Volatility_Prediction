# %% [markdown]
# ## Imports

# %%
import os
import random
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import missingno as msno


import sys

# Set all seeds
seed_value = 42
os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
RANDOM_STATE = 42

# %%
sys.path.append("../src")
from neural_networks.utils import calculate_historical_volatility, calculate_metrics, plot_predictions_vs_actual, create_sliding_window_dataset, split_data, prepare_time_series_data, evaluate_and_visualize_model, add_technical_indicators, add_predictive_features, add_volatility_features, select_features_with_rfecv, create_lstm_tuned_model, create_gru_model

# %%
df=pd.read_csv("../data_macro.csv")

# %%
df.head()
# Out:
#          date  eurusd_close  eurusd_open  eurusd_high  eurusd_low  \
# 0  2018-04-03      1.229271     1.229332     1.233700    1.225505
# 1  2018-04-04      1.227853     1.227943     1.231057    1.225761
# 2  2018-04-05      1.228682     1.228788     1.229105    1.221941
# 3  2018-04-06      1.225160     1.225100     1.228003    1.221807
# 4  2018-04-09      1.227144     1.227144     1.233046    1.226257
#
#          sp500  euro_stoxx_600           dax  SOFR  ester  BEIR_10Y_US  \
# 0  2614.449951      369.070007  12002.450195  1.83 -0.452         2.08
# 1  2644.689941      367.329987  11957.900391  1.74 -0.454         2.08
# 2  2662.840088      376.130005  12305.190430  1.75 -0.453         2.08
# 3  2604.469971      374.820007  12241.269531  1.75 -0.453         2.07
# 4  2613.159912      375.299988  12261.750000  1.75 -0.453         2.07
#
#    BEIR_10Y_EU  DGS10  DGS3MO  EURO_IR_3MO  EURO_IR_10Y
# 0        1.518   2.79    1.75    -0.660035     0.552061
# 1        1.511   2.79    1.71    -0.664585     0.547333
# 2        1.509   2.83    1.72    -0.659658     0.570174
# 3        1.510   2.77    1.73    -0.664742     0.559924
# 4        1.508   2.78    1.76    -0.657340     0.561172

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Data preprocessing

# %%
import numpy as np

df['return_eurousd'] = np.log(df['eurusd_close'] / df['eurusd_close'].shift(1))
df['return_sp500'] = np.log(df['sp500'] / df['sp500'].shift(1))
df['return_dax'] = np.log(df['dax'] / df['dax'].shift(1))

df["Spread_rate"]=df["ester"]-df["SOFR"]
df["Spread_inflation"]=df["BEIR_10Y_EU"]-df["BEIR_10Y_US"]

df['return_sofr'] = df['SOFR'].pct_change() 
df['return_ester'] = df['ester'].pct_change()
df['return_BEIR_10Y_US'] = df['BEIR_10Y_US'].pct_change()
df['return_BEIR_10Y_EU'] = df['BEIR_10Y_EU'].pct_change()

df['return_DGS10'] = df['DGS10'].pct_change()
df['return_DGS3MO'] = df['DGS3MO'].pct_change()

df['return_EURO_IR_3MO'] = df['EURO_IR_3MO'].pct_change()
df['return_EURO_IR_10Y'] = df['EURO_IR_10Y'].pct_change()


df["return_Spread_rate"] = df["Spread_rate"].pct_change()
df["return_Spread_inflation"] = df["Spread_inflation"].pct_change()

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df = df.fillna(method='ffill')
df = df.dropna()

# %%
df["date"] = pd.to_datetime(df['date'])

# %%
# Return data already calculated
returns = df['return_eurousd']

# Calculate historical volatility
hv = calculate_historical_volatility(returns)
df['historical_volatility'] = hv

df.head()
# Out:
#         date  eurusd_close  eurusd_open  eurusd_high  eurusd_low        sp500  \
# 1 2018-04-04      1.227853     1.227943     1.231057    1.225761  2644.689941
# 2 2018-04-05      1.228682     1.228788     1.229105    1.221941  2662.840088
# 3 2018-04-06      1.225160     1.225100     1.228003    1.221807  2604.469971
# 4 2018-04-09      1.227144     1.227144     1.233046    1.226257  2613.159912
# 5 2018-04-10      1.232240     1.232225     1.237777    1.230376  2656.870117
#
#    euro_stoxx_600           dax  SOFR  ester  ...  return_ester  \
# 1      367.329987  11957.900391  1.74 -0.454  ...      0.004425
# 2      376.130005  12305.190430  1.75 -0.453  ...     -0.002203
# 3      374.820007  12241.269531  1.75 -0.453  ...      0.000000
# 4      375.299988  12261.750000  1.75 -0.453  ...      0.000000
# 5      378.420013  12397.320312  1.75 -0.453  ...      0.000000
#
#    return_BEIR_10Y_US  return_BEIR_10Y_EU  return_DGS10  return_DGS3MO  \
# 1            0.000000           -0.004611      0.000000      -0.022857
# 2            0.000000           -0.001324      0.014337       0.005848
# 3           -0.004808            0.000663     -0.021201       0.005814
# 4            0.000000           -0.001325      0.003610       0.017341
# 5            0.004831            0.006631      0.007194      -0.011364
#
#    return_EURO_IR_3MO  return_EURO_IR_10Y  return_Spread_rate  \
# 1            0.006894           -0.008564           -0.038563
# 2           -0.007414            0.041731            0.004102
# 3            0.007707           -0.017977            0.000000
# 4           -0.011135            0.002229            0.000000
# 5           -0.007450            0.006353            0.000000
#
#    return_Spread_inflation  historical_volatility
# 1             1.245552e-02                    NaN
# 2             3.514938e-03                    NaN
# 3            -1.926445e-02                    NaN
# 4             3.571429e-03                    NaN
# 5             4.440892e-16                    NaN
#
# [5 rows x 32 columns]

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df = df.dropna()

# %% [markdown]
# ## Integrating ARCH models predictions for the hybrid model

# %%
# Add ARCH-based features
print("Adding GARCH features...")

df_with_garch = add_volatility_features(
    df,
    return_col='return_eurousd',
    window_size=30,
    stride=1,
    forecast_horizon=1
)
df_with_garch = df_with_garch.replace([np.inf, -np.inf], np.nan)
# Out:
# Adding GARCH features...
# Traitement de t = 100/1816
# Traitement de t = 200/1816
# Traitement de t = 300/1816
# Traitement de t = 400/1816
# Traitement de t = 500/1816
# Traitement de t = 600/1816
# Traitement de t = 700/1816
# Traitement de t = 800/1816
# Traitement de t = 900/1816
# Traitement de t = 1000/1816
# Traitement de t = 1100/1816
# Traitement de t = 1200/1816
# Traitement de t = 1300/1816
# Traitement de t = 1400/1816
# Traitement de t = 1500/1816
# Traitement de t = 1600/1816
# Traitement de t = 1700/1816
# Traitement de t = 1800/1816

# %%
msno.matrix(df_with_garch)
# Out:
# <Axes: >

# %%
df_with_garch = df_with_garch.fillna(method='ffill')
df_with_garch = df_with_garch.dropna()

# %% [markdown]
# ## Feature engineering

# %%
df_enhanced = add_predictive_features(df_with_garch)

df_enhanced = df_enhanced.replace([np.inf, -np.inf], np.nan)

# %%
msno.matrix(df_enhanced)
# Out:
# <Axes: >

# %%
df_enhanced = df_enhanced.fillna(method='ffill')
df_enhanced = df_enhanced.dropna()

# %%
df_technical = add_technical_indicators(df_enhanced, column='historical_volatility')

df_technical = df_technical.replace([np.inf, -np.inf], np.nan)

# %%
msno.matrix(df_technical)
# Out:
# <Axes: >

# %%
df_technical = df_technical.dropna()

# %%
# Print the number of inf and NaN values in each column before proceeding
print("Number of inf and NaN in each column:")
for col in df_technical.columns:
    num_inf = np.isinf(df_technical[col]).sum()
    num_nan = df_technical[col].isna().sum()
    print(f"{col}: inf = {num_inf}, NaN = {num_nan}")
# Out:
# Number of inf and NaN in each column:
# date: inf = 0, NaN = 0
# eurusd_close: inf = 0, NaN = 0
# eurusd_open: inf = 0, NaN = 0
# eurusd_high: inf = 0, NaN = 0
# eurusd_low: inf = 0, NaN = 0
# sp500: inf = 0, NaN = 0
# euro_stoxx_600: inf = 0, NaN = 0
# dax: inf = 0, NaN = 0
# SOFR: inf = 0, NaN = 0
# ester: inf = 0, NaN = 0
# BEIR_10Y_US: inf = 0, NaN = 0
# BEIR_10Y_EU: inf = 0, NaN = 0
# DGS10: inf = 0, NaN = 0
# DGS3MO: inf = 0, NaN = 0
# EURO_IR_3MO: inf = 0, NaN = 0
# EURO_IR_10Y: inf = 0, NaN = 0
# return_eurousd: inf = 0, NaN = 0
# return_sp500: inf = 0, NaN = 0
# return_dax: inf = 0, NaN = 0
# Spread_rate: inf = 0, NaN = 0
# Spread_inflation: inf = 0, NaN = 0
# return_sofr: inf = 0, NaN = 0
# return_ester: inf = 0, NaN = 0
# return_BEIR_10Y_US: inf = 0, NaN = 0
# return_BEIR_10Y_EU: inf = 0, NaN = 0
# return_DGS10: inf = 0, NaN = 0
# return_DGS3MO: inf = 0, NaN = 0
# return_EURO_IR_3MO: inf = 0, NaN = 0
# return_EURO_IR_10Y: inf = 0, NaN = 0
# return_Spread_rate: inf = 0, NaN = 0
# return_Spread_inflation: inf = 0, NaN = 0
# historical_volatility: inf = 0, NaN = 0
# garch_alpha: inf = 0, NaN = 0
# garch_beta: inf = 0, NaN = 0
# garch_omega: inf = 0, NaN = 0
# egarch_omega: inf = 0, NaN = 0
# egarch_alpha: inf = 0, NaN = 0
# egarch_beta: inf = 0, NaN = 0
# ewma_lambda: inf = 0, NaN = 0
# garch_forecast: inf = 0, NaN = 0
# egarch_forecast: inf = 0, NaN = 0
# ewma_forecast: inf = 0, NaN = 0
# garch_persistence: inf = 0, NaN = 0
# return_eurousd_vol_7d: inf = 0, NaN = 0
# return_sp500_vol_7d: inf = 0, NaN = 0
# return_dax_vol_7d: inf = 0, NaN = 0
# return_sofr_vol_7d: inf = 0, NaN = 0
# return_ester_vol_7d: inf = 0, NaN = 0
# return_BEIR_10Y_US_vol_7d: inf = 0, NaN = 0
# return_BEIR_10Y_EU_vol_7d: inf = 0, NaN = 0
# return_DGS10_vol_7d: inf = 0, NaN = 0
# return_DGS3MO_vol_7d: inf = 0, NaN = 0
# return_EURO_IR_3MO_vol_7d: inf = 0, NaN = 0
# return_EURO_IR_10Y_vol_7d: inf = 0, NaN = 0
# return_Spread_rate_vol_7d: inf = 0, NaN = 0
# return_Spread_inflation_vol_7d: inf = 0, NaN = 0
# corr_eurusd_sp500: inf = 0, NaN = 0
# corr_eurusd_dax: inf = 0, NaN = 0
# corr_sofr_ester: inf = 0, NaN = 0
# spread_sp500_dax: inf = 0, NaN = 0
# return_eurousd_trend: inf = 0, NaN = 0
# return_sp500_trend: inf = 0, NaN = 0
# return_dax_trend: inf = 0, NaN = 0
# return_sofr_trend: inf = 0, NaN = 0
# return_ester_trend: inf = 0, NaN = 0
# return_BEIR_10Y_US_trend: inf = 0, NaN = 0
# return_BEIR_10Y_EU_trend: inf = 0, NaN = 0
# return_DGS10_trend: inf = 0, NaN = 0
# return_DGS3MO_trend: inf = 0, NaN = 0
# return_EURO_IR_3MO_trend: inf = 0, NaN = 0
# return_EURO_IR_10Y_trend: inf = 0, NaN = 0
# return_Spread_rate_trend: inf = 0, NaN = 0
# return_Spread_inflation_trend: inf = 0, NaN = 0
# return_eurousd_zscore: inf = 0, NaN = 0
# return_sp500_zscore: inf = 0, NaN = 0
# return_dax_zscore: inf = 0, NaN = 0
# return_sofr_zscore: inf = 0, NaN = 0
# return_ester_zscore: inf = 0, NaN = 0
# return_BEIR_10Y_US_zscore: inf = 0, NaN = 0
# return_BEIR_10Y_EU_zscore: inf = 0, NaN = 0
# return_DGS10_zscore: inf = 0, NaN = 0
# return_DGS3MO_zscore: inf = 0, NaN = 0
# return_EURO_IR_3MO_zscore: inf = 0, NaN = 0
# return_EURO_IR_10Y_zscore: inf = 0, NaN = 0
# return_Spread_rate_zscore: inf = 0, NaN = 0
# return_Spread_inflation_zscore: inf = 0, NaN = 0
# vol_ratio_sp500_eurusd: inf = 0, NaN = 0
# eurusd_cum_return_short: inf = 0, NaN = 0
# eurusd_skew: inf = 0, NaN = 0
# volatility_regime_change: inf = 0, NaN = 0
# vol_growth: inf = 0, NaN = 0
# vol_acceleration: inf = 0, NaN = 0
# return_eurousd_jump_indicator: inf = 0, NaN = 0
# return_eurousd_recent_jumps: inf = 0, NaN = 0
# return_sp500_jump_indicator: inf = 0, NaN = 0
# return_sp500_recent_jumps: inf = 0, NaN = 0
# return_dax_jump_indicator: inf = 0, NaN = 0
# return_dax_recent_jumps: inf = 0, NaN = 0
# return_sofr_jump_indicator: inf = 0, NaN = 0
# return_sofr_recent_jumps: inf = 0, NaN = 0
# return_ester_jump_indicator: inf = 0, NaN = 0
# return_ester_recent_jumps: inf = 0, NaN = 0
# return_BEIR_10Y_US_jump_indicator: inf = 0, NaN = 0
# return_BEIR_10Y_US_recent_jumps: inf = 0, NaN = 0
# return_BEIR_10Y_EU_jump_indicator: inf = 0, NaN = 0
# return_BEIR_10Y_EU_recent_jumps: inf = 0, NaN = 0
# return_DGS10_jump_indicator: inf = 0, NaN = 0
# return_DGS10_recent_jumps: inf = 0, NaN = 0
# return_DGS3MO_jump_indicator: inf = 0, NaN = 0
# return_DGS3MO_recent_jumps: inf = 0, NaN = 0
# return_EURO_IR_3MO_jump_indicator: inf = 0, NaN = 0
# return_EURO_IR_3MO_recent_jumps: inf = 0, NaN = 0
# return_EURO_IR_10Y_jump_indicator: inf = 0, NaN = 0
# return_EURO_IR_10Y_recent_jumps: inf = 0, NaN = 0
# return_Spread_rate_jump_indicator: inf = 0, NaN = 0
# return_Spread_rate_recent_jumps: inf = 0, NaN = 0
# return_Spread_inflation_jump_indicator: inf = 0, NaN = 0
# return_Spread_inflation_recent_jumps: inf = 0, NaN = 0
# vol_of_vol: inf = 0, NaN = 0
# ewm_vol_ratio: inf = 0, NaN = 0
# correlation_regime_change: inf = 0, NaN = 0
# historical_volatility_middle_band: inf = 0, NaN = 0
# historical_volatility_upper_band: inf = 0, NaN = 0
# historical_volatility_lower_band: inf = 0, NaN = 0
# historical_volatility_momentum: inf = 0, NaN = 0
# historical_volatility_acceleration: inf = 0, NaN = 0
# historical_volatility_ema: inf = 0, NaN = 0
# historical_volatility_rsi: inf = 0, NaN = 0
# historical_volatility_macd_line: inf = 0, NaN = 0
# historical_volatility_macd_signal: inf = 0, NaN = 0
# historical_volatility_macd_hist: inf = 0, NaN = 0

# %% [markdown]
# ## Feature selection using RFECV

# %%
# Apply feature selection with RFECV
print("Selecting features via RFECV...")
df_final, selected_features = select_features_with_rfecv(
    df_technical,
    target_col='historical_volatility',
    train_ratio=0.7,
    val_ratio=0.15,
    date_col='date',
    step=1,
    min_features=13
)
# Out:
# Selecting features via RFECV...
# Exécution de RFECV pour sélectionner les meilleures caractéristiques...
# Fitting estimator with 129 features.
# Fitting estimator with 129 features.
# Fitting estimator with 129 features.
# Fitting estimator with 129 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 128 features.
# Fitting estimator with 128 features.
# Fitting estimator with 128 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 127 features.
# Fitting estimator with 127 features.
# Fitting estimator with 127 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 126 features.
# Fitting estimator with 126 features.
# Fitting estimator with 126 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 125 features.
# Fitting estimator with 125 features.
# Fitting estimator with 125 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 124 features.
# Fitting estimator with 124 features.
# Fitting estimator with 124 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 123 features.
# Fitting estimator with 123 features.
# Fitting estimator with 123 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 122 features.
# Fitting estimator with 122 features.
# Fitting estimator with 122 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 121 features.
# Fitting estimator with 121 features.
# Fitting estimator with 121 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 120 features.
# Fitting estimator with 120 features.
# Fitting estimator with 120 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 119 features.
# Fitting estimator with 119 features.
# Fitting estimator with 119 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 118 features.
# Fitting estimator with 118 features.
# Fitting estimator with 118 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 117 features.
# Fitting estimator with 117 features.
# Fitting estimator with 117 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 116 features.
# Fitting estimator with 116 features.
# Fitting estimator with 116 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 115 features.
# Fitting estimator with 115 features.
# Fitting estimator with 115 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 114 features.
# Fitting estimator with 114 features.
# Fitting estimator with 114 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 113 features.
# Fitting estimator with 113 features.
# Fitting estimator with 113 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 112 features.
# Fitting estimator with 112 features.
# Fitting estimator with 112 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 111 features.
# Fitting estimator with 111 features.
# Fitting estimator with 111 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 110 features.
# Fitting estimator with 110 features.
# Fitting estimator with 110 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 109 features.
# Fitting estimator with 109 features.
# Fitting estimator with 109 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 108 features.
# Fitting estimator with 108 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 107 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 106 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 105 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 104 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 103 features.
# Fitting estimator with 103 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 102 features.
# Fitting estimator with 102 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 101 features.
# Fitting estimator with 101 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 100 features.
# Fitting estimator with 100 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 99 features.
# Fitting estimator with 99 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 98 features.
# Fitting estimator with 98 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 97 features.
# Fitting estimator with 97 features.
# Fitting estimator with 97 features.
# Fitting estimator with 98 features.
# Fitting estimator with 96 features.
# Fitting estimator with 96 features.
# Fitting estimator with 96 features.
# Fitting estimator with 96 features.
# Fitting estimator with 97 features.
# Fitting estimator with 95 features.
# Fitting estimator with 95 features.
# Fitting estimator with 95 features.
# Fitting estimator with 95 features.
# Fitting estimator with 96 features.
# Fitting estimator with 94 features.
# Fitting estimator with 94 features.
# Fitting estimator with 94 features.
# Fitting estimator with 94 features.
# Fitting estimator with 95 features.
# Fitting estimator with 93 features.
# Fitting estimator with 93 features.
# Fitting estimator with 93 features.
# Fitting estimator with 93 features.
# Fitting estimator with 94 features.
# Fitting estimator with 92 features.
# Fitting estimator with 92 features.
# Fitting estimator with 92 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 93 features.
# Fitting estimator with 91 features.
# Fitting estimator with 91 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 90 features.
# Fitting estimator with 92 features.
# Fitting estimator with 90 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 89 features.
# Fitting estimator with 89 features.
# Fitting estimator with 91 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 88 features.
# Fitting estimator with 88 features.
# Fitting estimator with 90 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 87 features.
# Fitting estimator with 87 features.
# Fitting estimator with 89 features.
# Fitting estimator with 86 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 86 features.
# Fitting estimator with 88 features.
# Fitting estimator with 85 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 85 features.
# Fitting estimator with 87 features.
# Fitting estimator with 84 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 84 features.
# Fitting estimator with 86 features.
# Fitting estimator with 83 features.
# Fitting estimator with 83 features.
# Fitting estimator with 83 features.
# Fitting estimator with 84 features.
# Fitting estimator with 85 features.
# Fitting estimator with 82 features.
# Fitting estimator with 82 features.
# Fitting estimator with 82 features.
# Fitting estimator with 83 features.
# Fitting estimator with 84 features.
# Fitting estimator with 81 features.
# Fitting estimator with 81 features.
# Fitting estimator with 81 features.
# Fitting estimator with 82 features.
# Fitting estimator with 83 features.
# Fitting estimator with 80 features.
# Fitting estimator with 80 features.
# Fitting estimator with 80 features.
# Fitting estimator with 81 features.
# Fitting estimator with 79 features.
# Fitting estimator with 82 features.
# Fitting estimator with 79 features.
# Fitting estimator with 79 features.
# Fitting estimator with 80 features.
# Fitting estimator with 78 features.
# Fitting estimator with 78 features.
# Fitting estimator with 78 features.
# Fitting estimator with 81 features.
# Fitting estimator with 79 features.
# Fitting estimator with 77 features.
# Fitting estimator with 77 features.
# Fitting estimator with 77 features.
# Fitting estimator with 80 features.
# Fitting estimator with 78 features.
# Fitting estimator with 76 features.
# Fitting estimator with 76 features.
# Fitting estimator with 76 features.
# Fitting estimator with 79 features.
# Fitting estimator with 77 features.
# Fitting estimator with 75 features.
# Fitting estimator with 75 features.
# Fitting estimator with 75 features.
# Fitting estimator with 76 features.
# Fitting estimator with 78 features.
# Fitting estimator with 74 features.
# Fitting estimator with 74 features.
# Fitting estimator with 74 features.
# Fitting estimator with 75 features.
# Fitting estimator with 77 features.
# Fitting estimator with 73 features.
# Fitting estimator with 73 features.
# Fitting estimator with 73 features.
# Fitting estimator with 74 features.
# Fitting estimator with 76 features.
# Fitting estimator with 72 features.
# Fitting estimator with 72 features.
# Fitting estimator with 72 features.
# Fitting estimator with 73 features.
# Fitting estimator with 75 features.
# Fitting estimator with 71 features.
# Fitting estimator with 71 features.
# Fitting estimator with 71 features.
# Fitting estimator with 72 features.
# Fitting estimator with 74 features.
# Fitting estimator with 70 features.
# Fitting estimator with 70 features.
# Fitting estimator with 70 features.
# Fitting estimator with 71 features.
# Fitting estimator with 73 features.
# Fitting estimator with 69 features.
# Fitting estimator with 69 features.
# Fitting estimator with 69 features.
# Fitting estimator with 70 features.
# Fitting estimator with 72 features.
# Fitting estimator with 68 features.
# Fitting estimator with 68 features.
# Fitting estimator with 68 features.
# Fitting estimator with 69 features.
# Fitting estimator with 67 features.
# Fitting estimator with 71 features.
# Fitting estimator with 67 features.
# Fitting estimator with 67 features.
# Fitting estimator with 68 features.
# Fitting estimator with 66 features.
# Fitting estimator with 66 features.
# Fitting estimator with 66 features.
# Fitting estimator with 70 features.
# Fitting estimator with 67 features.
# Fitting estimator with 65 features.
# Fitting estimator with 65 features.
# Fitting estimator with 65 features.
# Fitting estimator with 69 features.
# Fitting estimator with 66 features.
# Fitting estimator with 64 features.
# Fitting estimator with 64 features.
# Fitting estimator with 64 features.
# Fitting estimator with 68 features.
# Fitting estimator with 65 features.
# Fitting estimator with 63 features.
# Fitting estimator with 63 features.
# Fitting estimator with 63 features.
# Fitting estimator with 67 features.
# Fitting estimator with 64 features.
# Fitting estimator with 62 features.
# Fitting estimator with 62 features.
# Fitting estimator with 62 features.
# Fitting estimator with 66 features.
# Fitting estimator with 61 features.
# Fitting estimator with 63 features.
# Fitting estimator with 61 features.
# Fitting estimator with 61 features.
# Fitting estimator with 65 features.
# Fitting estimator with 60 features.
# Fitting estimator with 60 features.
# Fitting estimator with 62 features.
# Fitting estimator with 60 features.
# Fitting estimator with 64 features.
# Fitting estimator with 59 features.
# Fitting estimator with 59 features.
# Fitting estimator with 59 features.
# Fitting estimator with 61 features.
# Fitting estimator with 58 features.
# Fitting estimator with 63 features.
# Fitting estimator with 58 features.
# Fitting estimator with 58 features.
# Fitting estimator with 60 features.
# Fitting estimator with 57 features.
# Fitting estimator with 57 features.
# Fitting estimator with 62 features.
# Fitting estimator with 57 features.
# Fitting estimator with 59 features.
# Fitting estimator with 56 features.
# Fitting estimator with 56 features.
# Fitting estimator with 56 features.
# Fitting estimator with 61 features.
# Fitting estimator with 58 features.
# Fitting estimator with 55 features.
# Fitting estimator with 55 features.
# Fitting estimator with 55 features.
# Fitting estimator with 57 features.
# Fitting estimator with 60 features.
# Fitting estimator with 54 features.
# Fitting estimator with 54 features.
# Fitting estimator with 54 features.
# Fitting estimator with 56 features.
# Fitting estimator with 59 features.
# Fitting estimator with 53 features.
# Fitting estimator with 53 features.
# Fitting estimator with 53 features.
# Fitting estimator with 55 features.
# Fitting estimator with 58 features.
# Fitting estimator with 52 features.
# Fitting estimator with 52 features.
# Fitting estimator with 52 features.
# Fitting estimator with 54 features.
# Fitting estimator with 57 features.
# Fitting estimator with 51 features.
# Fitting estimator with 51 features.
# Fitting estimator with 51 features.
# Fitting estimator with 53 features.
# Fitting estimator with 50 features.
# Fitting estimator with 50 features.
# Fitting estimator with 56 features.
# Fitting estimator with 50 features.
# Fitting estimator with 52 features.
# Fitting estimator with 49 features.
# Fitting estimator with 49 features.
# Fitting estimator with 49 features.
# Fitting estimator with 55 features.
# Fitting estimator with 51 features.
# Fitting estimator with 48 features.
# Fitting estimator with 48 features.
# Fitting estimator with 48 features.
# Fitting estimator with 54 features.
# Fitting estimator with 50 features.
# Fitting estimator with 47 features.
# Fitting estimator with 47 features.
# Fitting estimator with 47 features.
# Fitting estimator with 53 features.
# Fitting estimator with 46 features.
# Fitting estimator with 49 features.
# Fitting estimator with 46 features.
# Fitting estimator with 46 features.
# Fitting estimator with 52 features.
# Fitting estimator with 45 features.
# Fitting estimator with 45 features.
# Fitting estimator with 48 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 44 features.
# Fitting estimator with 51 features.
# Fitting estimator with 47 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 43 features.
# Fitting estimator with 50 features.
# Fitting estimator with 46 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 42 features.
# Fitting estimator with 45 features.
# Fitting estimator with 42 features.
# Fitting estimator with 49 features.
# Fitting estimator with 41 features.
# Fitting estimator with 41 features.
# Fitting estimator with 41 features.
# Fitting estimator with 44 features.
# Fitting estimator with 48 features.
# Fitting estimator with 40 features.
# Fitting estimator with 40 features.
# Fitting estimator with 40 features.
# Fitting estimator with 43 features.
# Fitting estimator with 39 features.
# Fitting estimator with 47 features.
# Fitting estimator with 39 features.
# Fitting estimator with 39 features.
# Fitting estimator with 42 features.
# Fitting estimator with 38 features.
# Fitting estimator with 38 features.
# Fitting estimator with 46 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 41 features.
# Fitting estimator with 37 features.
# Fitting estimator with 45 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 36 features.
# Fitting estimator with 40 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 44 features.
# Fitting estimator with 35 features.
# Fitting estimator with 39 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 34 features.
# Fitting estimator with 43 features.
# Fitting estimator with 38 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 33 features.
# Fitting estimator with 42 features.
# Fitting estimator with 37 features.
# Fitting estimator with 32 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 36 features.
# Fitting estimator with 31 features.
# Fitting estimator with 32 features.
# Fitting estimator with 41 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 31 features.
# Fitting estimator with 35 features.
# Fitting estimator with 30 features.
# Fitting estimator with 40 features.
# Fitting estimator with 29 features.
# Fitting estimator with 30 features.
# Fitting estimator with 34 features.
# Fitting estimator with 29 features.
# Fitting estimator with 39 features.
# Fitting estimator with 28 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 33 features.
# Fitting estimator with 27 features.
# Fitting estimator with 28 features.
# Fitting estimator with 38 features.
# Fitting estimator with 27 features.
# Fitting estimator with 32 features.
# Fitting estimator with 26 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 37 features.
# Fitting estimator with 25 features.
# Fitting estimator with 31 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 36 features.
# Fitting estimator with 30 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 29 features.
# Fitting estimator with 35 features.
# Fitting estimator with 22 features.
# Fitting estimator with 22 features.
# Fitting estimator with 23 features.
# Fitting estimator with 21 features.
# Fitting estimator with 28 features.
# Fitting estimator with 34 features.
# Fitting estimator with 21 features.
# Fitting estimator with 22 features.
# Fitting estimator with 20 features.
# Fitting estimator with 27 features.
# Fitting estimator with 20 features.
# Fitting estimator with 21 features.
# Fitting estimator with 19 features.
# Fitting estimator with 33 features.
# Fitting estimator with 19 features.
# Fitting estimator with 26 features.
# Fitting estimator with 18 features.
# Fitting estimator with 20 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 19 features.
# Fitting estimator with 32 features.
# Fitting estimator with 25 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 18 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 24 features.
# Fitting estimator with 31 features.
# Fitting estimator with 17 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 16 features.
# Fitting estimator with 23 features.
# Fitting estimator with 14 features.
# Fitting estimator with 30 features.
# Fitting estimator with 15 features.
# Fitting estimator with 22 features.
# Fitting estimator with 14 features.
# Fitting estimator with 29 features.
# Fitting estimator with 21 features.
# Fitting estimator with 28 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 27 features.
# Fitting estimator with 18 features.
# Fitting estimator with 26 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 25 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 129 features.
# Fitting estimator with 128 features.
# Fitting estimator with 127 features.
# Fitting estimator with 126 features.
# Fitting estimator with 125 features.
# Fitting estimator with 124 features.
# Fitting estimator with 123 features.
# Fitting estimator with 122 features.
# Fitting estimator with 121 features.
# Fitting estimator with 120 features.
# Fitting estimator with 119 features.
# Fitting estimator with 118 features.
# Fitting estimator with 117 features.
# Fitting estimator with 116 features.
# Fitting estimator with 115 features.
# Fitting estimator with 114 features.
# Fitting estimator with 113 features.
# Fitting estimator with 112 features.
# Fitting estimator with 111 features.
# Fitting estimator with 110 features.
# Fitting estimator with 109 features.
# Fitting estimator with 108 features.
# Fitting estimator with 107 features.
# Fitting estimator with 106 features.
# Fitting estimator with 105 features.
# Fitting estimator with 104 features.
# Fitting estimator with 103 features.
# Fitting estimator with 102 features.
# Fitting estimator with 101 features.
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Nombre optimal de caractéristiques: 20
# Caractéristiques sélectionnées: ['EURO_IR_3MO', 'garch_forecast', 'ewma_forecast', 'return_eurousd_vol_7d', 'return_BEIR_10Y_EU_vol_7d', 'return_EURO_IR_3MO_vol_7d', 'return_Spread_rate_trend', 'vol_growth', 'vol_acceleration', 'return_BEIR_10Y_US_recent_jumps', 'vol_of_vol', 'ewm_vol_ratio', 'historical_volatility_upper_band', 'historical_volatility_lower_band', 'historical_volatility_momentum', 'historical_volatility_ema', 'historical_volatility_rsi', 'historical_volatility_macd_line', 'historical_volatility_macd_signal', 'historical_volatility_macd_hist']

# %%
# Drop date column 
df_final = df_final.drop(columns="date", errors='ignore')

# %% [markdown]
# ## Model: LSTM and GRU

# %%
# Define features excluding historical_volatility 
feature_cols = [col for col in df_final.columns if col != 'historical_volatility']

# Prepare data
X_train, X_val, X_test, y_train, y_val, y_test, scaler_X, scaler_y = prepare_time_series_data(
    df_final, 
    feature_cols=feature_cols,  
    target_col='historical_volatility', 
    n_past=30,
    n_future=1, 
    stride=1,
    train_ratio=0.7, 
    val_ratio=0.15, 
    scale_data=True,
)
# Out:
# Data shapes:
# X_train: (1192, 30, 20), y_train: (1192, 1)
# X_val: (255, 30, 20), y_val: (255, 1)
# X_test: (256, 30, 20), y_test: (256, 1)

# %%
# Train the LSTM model 
input_shape = (X_train.shape[1], X_train.shape[2])
lstm_model = create_lstm_tuned_model(input_shape)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True, verbose=1
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=7, min_lr=0.00001, verbose=1
)

history = lstm_model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1,
    shuffle=False
)

# Evaluate the model
lstm_predictions_scaled = lstm_model.predict(X_test)
lstm_predictions = scaler_y.inverse_transform(lstm_predictions_scaled)
y_test_unscaled = scaler_y.inverse_transform(y_test)

lstm_mae, lstm_mse = evaluate_and_visualize_model(
    y_test_unscaled, 
    lstm_predictions, 
    model_name="LSTM-GARCH", 
    forecast_horizon=1,
    dates=df_technical['date'].iloc[-len(y_test):]
)
# Out:
# Epoch 1/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 0.1627 - mae: 0.3023 - val_loss: 0.0421 - val_mae: 0.0975 - learning_rate: 5.0000e-04
# Epoch 2/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.1756 - mae: 0.3176 - val_loss: 0.0338 - val_mae: 0.0612 - learning_rate: 5.0000e-04
# Epoch 3/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0485 - mae: 0.1068 - val_loss: 0.0511 - val_mae: 0.1332 - learning_rate: 5.0000e-04
# Epoch 4/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0573 - mae: 0.1371 - val_loss: 0.0675 - val_mae: 0.1804 - learning_rate: 5.0000e-04
# Epoch 5/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0532 - mae: 0.1245 - val_loss: 0.0948 - val_mae: 0.2490 - learning_rate: 5.0000e-04
# Epoch 6/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0365 - mae: 0.0774 - val_loss: 0.0394 - val_mae: 0.0990 - learning_rate: 5.0000e-04
# Epoch 7/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0333 - mae: 0.0622 - val_loss: 0.0336 - val_mae: 0.0725 - learning_rate: 5.0000e-04
# Epoch 8/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0331 - mae: 0.0614 - val_loss: 0.0287 - val_mae: 0.0450 - learning_rate: 5.0000e-04
# Epoch 9/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0300 - mae: 0.0503 - val_loss: 0.0319 - val_mae: 0.0705 - learning_rate: 5.0000e-04
# Epoch 10/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 0.0288 - mae: 0.0462 - val_loss: 0.0274 - val_mae: 0.0432 - learning_rate: 5.0000e-04
# Epoch 11/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0278 - mae: 0.0441 - val_loss: 0.0284 - val_mae: 0.0553 - learning_rate: 5.0000e-04
# Epoch 12/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0271 - mae: 0.0431 - val_loss: 0.0259 - val_mae: 0.0402 - learning_rate: 5.0000e-04
# Epoch 13/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0264 - mae: 0.0416 - val_loss: 0.0269 - val_mae: 0.0520 - learning_rate: 5.0000e-04
# Epoch 14/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0258 - mae: 0.0412 - val_loss: 0.0262 - val_mae: 0.0513 - learning_rate: 5.0000e-04
# Epoch 15/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0253 - mae: 0.0438 - val_loss: 0.0284 - val_mae: 0.0718 - learning_rate: 5.0000e-04
# Epoch 16/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0255 - mae: 0.0487 - val_loss: 0.0267 - val_mae: 0.0636 - learning_rate: 5.0000e-04
# Epoch 17/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0259 - mae: 0.0567 - val_loss: 0.0317 - val_mae: 0.0931 - learning_rate: 5.0000e-04
# Epoch 18/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0265 - mae: 0.0605 - val_loss: 0.0234 - val_mae: 0.0472 - learning_rate: 5.0000e-04
# Epoch 19/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0237 - mae: 0.0466 - val_loss: 0.0216 - val_mae: 0.0380 - learning_rate: 5.0000e-04
# Epoch 20/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0231 - mae: 0.0473 - val_loss: 0.0214 - val_mae: 0.0395 - learning_rate: 5.0000e-04
# Epoch 21/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 0.0280 - mae: 0.0764 - val_loss: 0.0231 - val_mae: 0.0580 - learning_rate: 5.0000e-04
# Epoch 22/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0327 - mae: 0.0995 - val_loss: 0.0333 - val_mae: 0.1130 - learning_rate: 5.0000e-04
# Epoch 23/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0320 - mae: 0.1009 - val_loss: 0.0199 - val_mae: 0.0404 - learning_rate: 5.0000e-04
# Epoch 24/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0228 - mae: 0.0568 - val_loss: 0.0193 - val_mae: 0.0390 - learning_rate: 5.0000e-04
# Epoch 25/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0231 - mae: 0.0642 - val_loss: 0.0231 - val_mae: 0.0746 - learning_rate: 5.0000e-04
# Epoch 26/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0190 - mae: 0.0395 - val_loss: 0.0183 - val_mae: 0.0387 - learning_rate: 5.0000e-04
# Epoch 27/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 0.0187 - mae: 0.0402 - val_loss: 0.0189 - val_mae: 0.0503 - learning_rate: 5.0000e-04
# Epoch 28/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0184 - mae: 0.0406 - val_loss: 0.0175 - val_mae: 0.0396 - learning_rate: 5.0000e-04
# Epoch 29/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0178 - mae: 0.0408 - val_loss: 0.0171 - val_mae: 0.0423 - learning_rate: 5.0000e-04
# Epoch 30/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0172 - mae: 0.0392 - val_loss: 0.0160 - val_mae: 0.0351 - learning_rate: 5.0000e-04
# Epoch 31/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0179 - mae: 0.0505 - val_loss: 0.0205 - val_mae: 0.0748 - learning_rate: 5.0000e-04
# Epoch 32/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0167 - mae: 0.0443 - val_loss: 0.0150 - val_mae: 0.0334 - learning_rate: 5.0000e-04
# Epoch 33/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0162 - mae: 0.0418 - val_loss: 0.0147 - val_mae: 0.0352 - learning_rate: 5.0000e-04
# Epoch 34/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0170 - mae: 0.0518 - val_loss: 0.0205 - val_mae: 0.0809 - learning_rate: 5.0000e-04
# Epoch 35/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0169 - mae: 0.0531 - val_loss: 0.0154 - val_mae: 0.0517 - learning_rate: 5.0000e-04
# Epoch 36/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0156 - mae: 0.0460 - val_loss: 0.0145 - val_mae: 0.0434 - learning_rate: 5.0000e-04
# Epoch 37/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0144 - mae: 0.0399 - val_loss: 0.0143 - val_mae: 0.0484 - learning_rate: 5.0000e-04
# Epoch 38/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0136 - mae: 0.0369 - val_loss: 0.0145 - val_mae: 0.0507 - learning_rate: 5.0000e-04
# Epoch 39/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0162 - mae: 0.0582 - val_loss: 0.0171 - val_mae: 0.0730 - learning_rate: 5.0000e-04
# Epoch 40/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0140 - mae: 0.0454 - val_loss: 0.0144 - val_mae: 0.0541 - learning_rate: 5.0000e-04
# Epoch 41/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0169 - mae: 0.0645 - val_loss: 0.0113 - val_mae: 0.0267 - learning_rate: 5.0000e-04
# Epoch 42/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0143 - mae: 0.0467 - val_loss: 0.0110 - val_mae: 0.0298 - learning_rate: 5.0000e-04
# Epoch 43/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0140 - mae: 0.0530 - val_loss: 0.0117 - val_mae: 0.0412 - learning_rate: 5.0000e-04
# Epoch 44/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0162 - mae: 0.0633 - val_loss: 0.0109 - val_mae: 0.0328 - learning_rate: 5.0000e-04
# Epoch 45/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0127 - mae: 0.0490 - val_loss: 0.0168 - val_mae: 0.0803 - learning_rate: 5.0000e-04
# Epoch 46/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0144 - mae: 0.0619 - val_loss: 0.0117 - val_mae: 0.0471 - learning_rate: 5.0000e-04
# Epoch 47/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0133 - mae: 0.0543 - val_loss: 0.0109 - val_mae: 0.0431 - learning_rate: 5.0000e-04
# Epoch 48/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0112 - mae: 0.0424 - val_loss: 0.0094 - val_mae: 0.0312 - learning_rate: 5.0000e-04
# Epoch 49/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0118 - mae: 0.0510 - val_loss: 0.0106 - val_mae: 0.0458 - learning_rate: 5.0000e-04
# Epoch 50/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0122 - mae: 0.0565 - val_loss: 0.0123 - val_mae: 0.0615 - learning_rate: 5.0000e-04
# Epoch 51/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0127 - mae: 0.0613 - val_loss: 0.0095 - val_mae: 0.0381 - learning_rate: 5.0000e-04
# Epoch 52/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0100 - mae: 0.0405 - val_loss: 0.0082 - val_mae: 0.0271 - learning_rate: 5.0000e-04
# Epoch 53/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0098 - mae: 0.0422 - val_loss: 0.0109 - val_mae: 0.0562 - learning_rate: 5.0000e-04
# Epoch 54/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0090 - mae: 0.0366 - val_loss: 0.0079 - val_mae: 0.0282 - learning_rate: 5.0000e-04
# Epoch 55/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0087 - mae: 0.0360 - val_loss: 0.0077 - val_mae: 0.0304 - learning_rate: 5.0000e-04
# Epoch 56/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0087 - mae: 0.0390 - val_loss: 0.0094 - val_mae: 0.0519 - learning_rate: 5.0000e-04
# Epoch 57/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0092 - mae: 0.0474 - val_loss: 0.0089 - val_mae: 0.0482 - learning_rate: 5.0000e-04
# Epoch 58/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0096 - mae: 0.0515 - val_loss: 0.0072 - val_mae: 0.0327 - learning_rate: 5.0000e-04
# Epoch 59/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0080 - mae: 0.0380 - val_loss: 0.0068 - val_mae: 0.0277 - learning_rate: 5.0000e-04
# Epoch 60/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0083 - mae: 0.0422 - val_loss: 0.0106 - val_mae: 0.0645 - learning_rate: 5.0000e-04
# Epoch 61/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0093 - mae: 0.0503 - val_loss: 0.0094 - val_mae: 0.0570 - learning_rate: 5.0000e-04
# Epoch 62/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0093 - mae: 0.0522 - val_loss: 0.0201 - val_mae: 0.1123 - learning_rate: 5.0000e-04
# Epoch 63/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0125 - mae: 0.0722 - val_loss: 0.0174 - val_mae: 0.1013 - learning_rate: 5.0000e-04
# Epoch 64/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0139 - mae: 0.0781 - val_loss: 0.0127 - val_mae: 0.0771 - learning_rate: 5.0000e-04
# Epoch 65/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0140 - mae: 0.0753 - val_loss: 0.0075 - val_mae: 0.0456 - learning_rate: 5.0000e-04
# Epoch 66/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0101 - mae: 0.0585
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0101 - mae: 0.0584 - val_loss: 0.0119 - val_mae: 0.0766 - learning_rate: 5.0000e-04
# Epoch 67/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0129 - mae: 0.0725 - val_loss: 0.0064 - val_mae: 0.0366 - learning_rate: 2.5000e-04
# Epoch 68/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0080 - mae: 0.0487 - val_loss: 0.0055 - val_mae: 0.0291 - learning_rate: 2.5000e-04
# Epoch 69/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0064 - mae: 0.0366 - val_loss: 0.0054 - val_mae: 0.0277 - learning_rate: 2.5000e-04
# Epoch 70/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0059 - mae: 0.0325 - val_loss: 0.0053 - val_mae: 0.0275 - learning_rate: 2.5000e-04
# Epoch 71/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0059 - mae: 0.0332 - val_loss: 0.0053 - val_mae: 0.0273 - learning_rate: 2.5000e-04
# Epoch 72/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0058 - mae: 0.0323 - val_loss: 0.0052 - val_mae: 0.0273 - learning_rate: 2.5000e-04
# Epoch 73/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0057 - mae: 0.0323 - val_loss: 0.0055 - val_mae: 0.0301 - learning_rate: 2.5000e-04
# Epoch 74/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0056 - mae: 0.0320 - val_loss: 0.0051 - val_mae: 0.0271 - learning_rate: 2.5000e-04
# Epoch 75/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0055 - mae: 0.0318 - val_loss: 0.0051 - val_mae: 0.0278 - learning_rate: 2.5000e-04
# Epoch 76/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0054 - mae: 0.0317 - val_loss: 0.0052 - val_mae: 0.0290 - learning_rate: 2.5000e-04
# Epoch 77/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0055 - mae: 0.0323 - val_loss: 0.0052 - val_mae: 0.0304 - learning_rate: 2.5000e-04
# Epoch 78/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0053 - mae: 0.0306 - val_loss: 0.0049 - val_mae: 0.0277 - learning_rate: 2.5000e-04
# Epoch 79/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0052 - mae: 0.0325 - val_loss: 0.0051 - val_mae: 0.0310 - learning_rate: 2.5000e-04
# Epoch 80/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0052 - mae: 0.0315 - val_loss: 0.0047 - val_mae: 0.0273 - learning_rate: 2.5000e-04
# Epoch 81/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0050 - mae: 0.0311 - val_loss: 0.0047 - val_mae: 0.0280 - learning_rate: 2.5000e-04
# Epoch 82/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0050 - mae: 0.0310 - val_loss: 0.0049 - val_mae: 0.0299 - learning_rate: 2.5000e-04
# Epoch 83/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0049 - mae: 0.0308 - val_loss: 0.0053 - val_mae: 0.0350 - learning_rate: 2.5000e-04
# Epoch 84/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0048 - mae: 0.0305 - val_loss: 0.0044 - val_mae: 0.0273 - learning_rate: 2.5000e-04
# Epoch 85/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0048 - mae: 0.0323 - val_loss: 0.0049 - val_mae: 0.0328 - learning_rate: 2.5000e-04
# Epoch 86/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0047 - mae: 0.0309 - val_loss: 0.0044 - val_mae: 0.0300 - learning_rate: 2.5000e-04
# Epoch 87/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0049 - mae: 0.0334 - val_loss: 0.0059 - val_mae: 0.0453 - learning_rate: 2.5000e-04
# Epoch 88/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0048 - mae: 0.0317 - val_loss: 0.0042 - val_mae: 0.0278 - learning_rate: 2.5000e-04
# Epoch 89/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0045 - mae: 0.0312 - val_loss: 0.0042 - val_mae: 0.0298 - learning_rate: 2.5000e-04
# Epoch 90/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0051 - mae: 0.0365 - val_loss: 0.0054 - val_mae: 0.0405 - learning_rate: 2.5000e-04
# Epoch 91/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0048 - mae: 0.0343 - val_loss: 0.0040 - val_mae: 0.0275 - learning_rate: 2.5000e-04
# Epoch 92/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0045 - mae: 0.0329 - val_loss: 0.0040 - val_mae: 0.0294 - learning_rate: 2.5000e-04
# Epoch 93/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0048 - mae: 0.0375 - val_loss: 0.0042 - val_mae: 0.0297 - learning_rate: 2.5000e-04
# Epoch 94/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0042 - mae: 0.0299 - val_loss: 0.0043 - val_mae: 0.0310 - learning_rate: 2.5000e-04
# Epoch 95/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0043 - mae: 0.0309 - val_loss: 0.0040 - val_mae: 0.0285 - learning_rate: 2.5000e-04
# Epoch 96/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0042 - mae: 0.0315 - val_loss: 0.0038 - val_mae: 0.0278 - learning_rate: 2.5000e-04
# Epoch 97/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0040 - mae: 0.0305 - val_loss: 0.0038 - val_mae: 0.0294 - learning_rate: 2.5000e-04
# Epoch 98/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0045 - mae: 0.0351 - val_loss: 0.0061 - val_mae: 0.0501 - learning_rate: 2.5000e-04
# Epoch 99/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 0.0052 - mae: 0.0414 - val_loss: 0.0044 - val_mae: 0.0351 - learning_rate: 2.5000e-04
# Epoch 100/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0045 - mae: 0.0356 - val_loss: 0.0039 - val_mae: 0.0331 - learning_rate: 2.5000e-04
# Epoch 101/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0053 - mae: 0.0441 - val_loss: 0.0044 - val_mae: 0.0367 - learning_rate: 2.5000e-04
# Epoch 102/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0042 - mae: 0.0338 - val_loss: 0.0040 - val_mae: 0.0313 - learning_rate: 2.5000e-04
# Epoch 103/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0043 - mae: 0.0344
# Epoch 103: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0043 - mae: 0.0344 - val_loss: 0.0037 - val_mae: 0.0330 - learning_rate: 2.5000e-04
# Epoch 104/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0048 - mae: 0.0412 - val_loss: 0.0038 - val_mae: 0.0307 - learning_rate: 1.2500e-04
# Epoch 105/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0037 - mae: 0.0304 - val_loss: 0.0037 - val_mae: 0.0298 - learning_rate: 1.2500e-04
# Epoch 106/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0037 - mae: 0.0307 - val_loss: 0.0036 - val_mae: 0.0288 - learning_rate: 1.2500e-04
# Epoch 107/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0037 - mae: 0.0307 - val_loss: 0.0037 - val_mae: 0.0300 - learning_rate: 1.2500e-04
# Epoch 108/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0036 - mae: 0.0308 - val_loss: 0.0034 - val_mae: 0.0280 - learning_rate: 1.2500e-04
# Epoch 109/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0036 - mae: 0.0313 - val_loss: 0.0036 - val_mae: 0.0293 - learning_rate: 1.2500e-04
# Epoch 110/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 0.0036 - mae: 0.0298 - val_loss: 0.0034 - val_mae: 0.0277 - learning_rate: 1.2500e-04
# Epoch 111/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0034 - mae: 0.0294 - val_loss: 0.0034 - val_mae: 0.0281 - learning_rate: 1.2500e-04
# Epoch 112/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 0.0035 - mae: 0.0298 - val_loss: 0.0034 - val_mae: 0.0288 - learning_rate: 1.2500e-04
# Epoch 113/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0034 - mae: 0.0292 - val_loss: 0.0033 - val_mae: 0.0277 - learning_rate: 1.2500e-04
# Epoch 114/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0034 - mae: 0.0295 - val_loss: 0.0035 - val_mae: 0.0298 - learning_rate: 1.2500e-04
# Epoch 115/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0034 - mae: 0.0296 - val_loss: 0.0035 - val_mae: 0.0297 - learning_rate: 1.2500e-04
# Epoch 116/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 0.0032 - mae: 0.0285 - val_loss: 0.0038 - val_mae: 0.0337 - learning_rate: 1.2500e-04
# Epoch 117/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0034 - mae: 0.0293 - val_loss: 0.0033 - val_mae: 0.0291 - learning_rate: 1.2500e-04
# Epoch 118/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 0.0034 - mae: 0.0292 - val_loss: 0.0036 - val_mae: 0.0318 - learning_rate: 1.2500e-04
# Epoch 119/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0033 - mae: 0.0294 - val_loss: 0.0034 - val_mae: 0.0295 - learning_rate: 1.2500e-04
# Epoch 120/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0032 - mae: 0.0291 - val_loss: 0.0031 - val_mae: 0.0277 - learning_rate: 1.2500e-04
# Epoch 121/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0034 - mae: 0.0319 - val_loss: 0.0040 - val_mae: 0.0369 - learning_rate: 1.2500e-04
# Epoch 122/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - loss: 0.0033 - mae: 0.0295 - val_loss: 0.0030 - val_mae: 0.0275 - learning_rate: 1.2500e-04
# Epoch 123/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 0.0032 - mae: 0.0296 - val_loss: 0.0040 - val_mae: 0.0384 - learning_rate: 1.2500e-04
# Epoch 124/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - loss: 0.0031 - mae: 0.0288 - val_loss: 0.0030 - val_mae: 0.0269 - learning_rate: 1.2500e-04
# Epoch 125/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 0.0031 - mae: 0.0295 - val_loss: 0.0044 - val_mae: 0.0432 - learning_rate: 1.2500e-04
# Epoch 126/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 0.0031 - mae: 0.0290 - val_loss: 0.0030 - val_mae: 0.0281 - learning_rate: 1.2500e-04
# Epoch 127/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 0.0032 - mae: 0.0306 - val_loss: 0.0036 - val_mae: 0.0345 - learning_rate: 1.2500e-04
# Epoch 128/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - loss: 0.0031 - mae: 0.0302 - val_loss: 0.0036 - val_mae: 0.0336 - learning_rate: 1.2500e-04
# Epoch 129/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 0.0032 - mae: 0.0316 - val_loss: 0.0029 - val_mae: 0.0274 - learning_rate: 1.2500e-04
# Epoch 130/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0031 - mae: 0.0299 - val_loss: 0.0029 - val_mae: 0.0284 - learning_rate: 1.2500e-04
# Epoch 131/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0035 - mae: 0.0339 - val_loss: 0.0055 - val_mae: 0.0540 - learning_rate: 1.2500e-04
# Epoch 132/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 0.0034 - mae: 0.0324 - val_loss: 0.0029 - val_mae: 0.0271 - learning_rate: 1.2500e-04
# Epoch 133/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0033 - mae: 0.0335 - val_loss: 0.0028 - val_mae: 0.0288 - learning_rate: 1.2500e-04
# Epoch 134/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0035 - mae: 0.0344 - val_loss: 0.0033 - val_mae: 0.0322 - learning_rate: 1.2500e-04
# Epoch 135/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0032 - mae: 0.0318 - val_loss: 0.0043 - val_mae: 0.0423 - learning_rate: 1.2500e-04
# Epoch 136/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0037 - mae: 0.0357 - val_loss: 0.0028 - val_mae: 0.0273 - learning_rate: 1.2500e-04
# Epoch 137/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0031 - mae: 0.0325 - val_loss: 0.0028 - val_mae: 0.0282 - learning_rate: 1.2500e-04
# Epoch 138/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 0.0034 - mae: 0.0349 - val_loss: 0.0036 - val_mae: 0.0368 - learning_rate: 1.2500e-04
# Epoch 139/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0029 - mae: 0.0292 - val_loss: 0.0033 - val_mae: 0.0332 - learning_rate: 1.2500e-04
# Epoch 140/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0030 - mae: 0.0307 - val_loss: 0.0027 - val_mae: 0.0276 - learning_rate: 1.2500e-04
# Epoch 141/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0031 - mae: 0.0332 - val_loss: 0.0035 - val_mae: 0.0361 - learning_rate: 1.2500e-04
# Epoch 142/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0029 - mae: 0.0288 - val_loss: 0.0032 - val_mae: 0.0322 - learning_rate: 1.2500e-04
# Epoch 143/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0029 - mae: 0.0293 - val_loss: 0.0035 - val_mae: 0.0366 - learning_rate: 1.2500e-04
# Epoch 144/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0029 - mae: 0.0300 - val_loss: 0.0027 - val_mae: 0.0277 - learning_rate: 1.2500e-04
# Epoch 145/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0031 - mae: 0.0324 - val_loss: 0.0038 - val_mae: 0.0397 - learning_rate: 1.2500e-04
# Epoch 146/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0027 - mae: 0.0294 - val_loss: 0.0037 - val_mae: 0.0377 - learning_rate: 1.2500e-04
# Epoch 147/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0032 - mae: 0.0333
# Epoch 147: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0032 - mae: 0.0333 - val_loss: 0.0028 - val_mae: 0.0283 - learning_rate: 1.2500e-04
# Epoch 148/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0028 - mae: 0.0307 - val_loss: 0.0028 - val_mae: 0.0291 - learning_rate: 6.2500e-05
# Epoch 149/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0031 - mae: 0.0338 - val_loss: 0.0030 - val_mae: 0.0310 - learning_rate: 6.2500e-05
# Epoch 150/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0027 - mae: 0.0304 - val_loss: 0.0028 - val_mae: 0.0289 - learning_rate: 6.2500e-05
# Epoch 151/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 0.0027 - mae: 0.0302 - val_loss: 0.0027 - val_mae: 0.0284 - learning_rate: 6.2500e-05
# Epoch 152/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 0.0026 - mae: 0.0303 - val_loss: 0.0027 - val_mae: 0.0278 - learning_rate: 6.2500e-05
# Epoch 153/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0028 - mae: 0.0312 - val_loss: 0.0029 - val_mae: 0.0309 - learning_rate: 6.2500e-05
# Epoch 154/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0026 - mae: 0.0289
# Epoch 154: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0026 - mae: 0.0290 - val_loss: 0.0029 - val_mae: 0.0301 - learning_rate: 6.2500e-05
# Epoch 155/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0025 - mae: 0.0283 - val_loss: 0.0028 - val_mae: 0.0292 - learning_rate: 3.1250e-05
# Epoch 156/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0025 - mae: 0.0283 - val_loss: 0.0028 - val_mae: 0.0298 - learning_rate: 3.1250e-05
# Epoch 157/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0026 - mae: 0.0294 - val_loss: 0.0028 - val_mae: 0.0295 - learning_rate: 3.1250e-05
# Epoch 158/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0026 - mae: 0.0290 - val_loss: 0.0028 - val_mae: 0.0290 - learning_rate: 3.1250e-05
# Epoch 159/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0027 - mae: 0.0307 - val_loss: 0.0028 - val_mae: 0.0297 - learning_rate: 3.1250e-05
# Epoch 160/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 0.0025 - mae: 0.0293 - val_loss: 0.0029 - val_mae: 0.0307 - learning_rate: 3.1250e-05
# Epoch 161/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0025 - mae: 0.0287
# Epoch 161: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0025 - mae: 0.0287 - val_loss: 0.0031 - val_mae: 0.0326 - learning_rate: 3.1250e-05
# Epoch 162/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 0.0025 - mae: 0.0283 - val_loss: 0.0031 - val_mae: 0.0337 - learning_rate: 1.5625e-05
# Epoch 163/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 0.0024 - mae: 0.0276 - val_loss: 0.0030 - val_mae: 0.0323 - learning_rate: 1.5625e-05
# Epoch 164/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0024 - mae: 0.0269 - val_loss: 0.0030 - val_mae: 0.0317 - learning_rate: 1.5625e-05
# Epoch 165/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0025 - mae: 0.0274 - val_loss: 0.0030 - val_mae: 0.0317 - learning_rate: 1.5625e-05
# Epoch 166/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - loss: 0.0025 - mae: 0.0277 - val_loss: 0.0031 - val_mae: 0.0328 - learning_rate: 1.5625e-05
# Epoch 167/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0026 - mae: 0.0286 - val_loss: 0.0030 - val_mae: 0.0316 - learning_rate: 1.5625e-05
# Epoch 168/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0024 - mae: 0.0271
# Epoch 168: ReduceLROnPlateau reducing learning rate to 1e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0025 - mae: 0.0271 - val_loss: 0.0030 - val_mae: 0.0316 - learning_rate: 1.5625e-05
# Epoch 169/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 0.0024 - mae: 0.0267 - val_loss: 0.0030 - val_mae: 0.0327 - learning_rate: 1.0000e-05
# Epoch 170/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - loss: 0.0025 - mae: 0.0276 - val_loss: 0.0030 - val_mae: 0.0320 - learning_rate: 1.0000e-05
# Epoch 171/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0026 - mae: 0.0288 - val_loss: 0.0030 - val_mae: 0.0325 - learning_rate: 1.0000e-05
# Epoch 172/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.0025 - mae: 0.0275 - val_loss: 0.0029 - val_mae: 0.0312 - learning_rate: 1.0000e-05
# Epoch 172: early stopping
# Restoring model weights from the end of the best epoch: 152.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
#
# Evaluation metrics:
# MAE: 0.001743
# MSE: 0.000011

# %%
# Plot training and validation loss to visualize training progress

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Train the GRU model
input_shape = (X_train.shape[1], X_train.shape[2])
gru_model = create_gru_model(input_shape)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True, verbose=1
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=7, min_lr=0.00001, verbose=1
)

history = gru_model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1,
    shuffle=False
)

# Evaluate the model
gru_predictions_scaled = gru_model.predict(X_test)
gru_predictions = scaler_y.inverse_transform(gru_predictions_scaled)
y_test_unscaled = scaler_y.inverse_transform(y_test)

gru_mae, gru_mse= evaluate_and_visualize_model(
    y_test_unscaled,
    gru_predictions,
    model_name="GRU-GARCH",
    forecast_horizon=1,
    dates = df_technical['date'].iloc[-len(y_test):]
)
# Out:
# Epoch 1/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - loss: 0.1812 - mae: 0.3075 - val_loss: 0.0346 - val_mae: 0.0587 - learning_rate: 5.0000e-04
# Epoch 2/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.1884 - mae: 0.3329 - val_loss: 0.2599 - val_mae: 0.4712 - learning_rate: 5.0000e-04
# Epoch 3/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.5844 - mae: 0.6001 - val_loss: 0.2050 - val_mae: 0.3967 - learning_rate: 5.0000e-04
# Epoch 4/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.2073 - mae: 0.3595 - val_loss: 0.0546 - val_mae: 0.1434 - learning_rate: 5.0000e-04
# Epoch 5/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0627 - mae: 0.1450 - val_loss: 0.0340 - val_mae: 0.0702 - learning_rate: 5.0000e-04
# Epoch 6/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0401 - mae: 0.0884 - val_loss: 0.0359 - val_mae: 0.0826 - learning_rate: 5.0000e-04
# Epoch 7/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0340 - mae: 0.0679 - val_loss: 0.0331 - val_mae: 0.0702 - learning_rate: 5.0000e-04
# Epoch 8/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0361 - mae: 0.0811 - val_loss: 0.0521 - val_mae: 0.1527 - learning_rate: 5.0000e-04
# Epoch 9/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0366 - mae: 0.0780 - val_loss: 0.0452 - val_mae: 0.1254 - learning_rate: 5.0000e-04
# Epoch 10/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0396 - mae: 0.0937 - val_loss: 0.1486 - val_mae: 0.3410 - learning_rate: 5.0000e-04
# Epoch 11/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0396 - mae: 0.0898 - val_loss: 0.0492 - val_mae: 0.1451 - learning_rate: 5.0000e-04
# Epoch 12/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0348 - mae: 0.0759 - val_loss: 0.0671 - val_mae: 0.1968 - learning_rate: 5.0000e-04
# Epoch 13/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 0.0318 - mae: 0.0666 - val_loss: 0.0275 - val_mae: 0.0532 - learning_rate: 5.0000e-04
# Epoch 14/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0275 - mae: 0.0474 - val_loss: 0.0357 - val_mae: 0.1003 - learning_rate: 5.0000e-04
# Epoch 15/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0270 - mae: 0.0458 - val_loss: 0.0252 - val_mae: 0.0388 - learning_rate: 5.0000e-04
# Epoch 16/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0262 - mae: 0.0434 - val_loss: 0.0297 - val_mae: 0.0737 - learning_rate: 5.0000e-04
# Epoch 17/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0258 - mae: 0.0437 - val_loss: 0.0246 - val_mae: 0.0385 - learning_rate: 5.0000e-04
# Epoch 18/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0246 - mae: 0.0373 - val_loss: 0.0265 - val_mae: 0.0570 - learning_rate: 5.0000e-04
# Epoch 19/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 0.0244 - mae: 0.0393 - val_loss: 0.0251 - val_mae: 0.0485 - learning_rate: 5.0000e-04
# Epoch 20/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0241 - mae: 0.0371 - val_loss: 0.0247 - val_mae: 0.0478 - learning_rate: 5.0000e-04
# Epoch 21/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0236 - mae: 0.0363 - val_loss: 0.0234 - val_mae: 0.0391 - learning_rate: 5.0000e-04
# Epoch 22/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0236 - mae: 0.0395 - val_loss: 0.0245 - val_mae: 0.0517 - learning_rate: 5.0000e-04
# Epoch 23/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0231 - mae: 0.0366 - val_loss: 0.0238 - val_mae: 0.0492 - learning_rate: 5.0000e-04
# Epoch 24/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0225 - mae: 0.0353 - val_loss: 0.0235 - val_mae: 0.0481 - learning_rate: 5.0000e-04
# Epoch 25/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0225 - mae: 0.0369 - val_loss: 0.0223 - val_mae: 0.0401 - learning_rate: 5.0000e-04
# Epoch 26/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0220 - mae: 0.0361 - val_loss: 0.0234 - val_mae: 0.0526 - learning_rate: 5.0000e-04
# Epoch 27/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0217 - mae: 0.0354 - val_loss: 0.0216 - val_mae: 0.0390 - learning_rate: 5.0000e-04
# Epoch 28/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0213 - mae: 0.0349 - val_loss: 0.0231 - val_mae: 0.0551 - learning_rate: 5.0000e-04
# Epoch 29/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0213 - mae: 0.0353 - val_loss: 0.0210 - val_mae: 0.0380 - learning_rate: 5.0000e-04
# Epoch 30/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0210 - mae: 0.0361 - val_loss: 0.0223 - val_mae: 0.0533 - learning_rate: 5.0000e-04
# Epoch 31/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0205 - mae: 0.0348 - val_loss: 0.0200 - val_mae: 0.0337 - learning_rate: 5.0000e-04
# Epoch 32/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0203 - mae: 0.0345 - val_loss: 0.0256 - val_mae: 0.0797 - learning_rate: 5.0000e-04
# Epoch 33/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0203 - mae: 0.0364 - val_loss: 0.0203 - val_mae: 0.0412 - learning_rate: 5.0000e-04
# Epoch 34/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0203 - mae: 0.0392 - val_loss: 0.0325 - val_mae: 0.1154 - learning_rate: 5.0000e-04
# Epoch 35/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0201 - mae: 0.0381 - val_loss: 0.0245 - val_mae: 0.0759 - learning_rate: 5.0000e-04
# Epoch 36/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0207 - mae: 0.0442 - val_loss: 0.0451 - val_mae: 0.1623 - learning_rate: 5.0000e-04
# Epoch 37/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0221 - mae: 0.0554 - val_loss: 0.0355 - val_mae: 0.1270 - learning_rate: 5.0000e-04
# Epoch 38/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0214 - mae: 0.0498
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0214 - mae: 0.0501 - val_loss: 0.0610 - val_mae: 0.2056 - learning_rate: 5.0000e-04
# Epoch 39/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0200 - mae: 0.0416 - val_loss: 0.0185 - val_mae: 0.0381 - learning_rate: 2.5000e-04
# Epoch 40/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - loss: 0.0183 - mae: 0.0350 - val_loss: 0.0212 - val_mae: 0.0617 - learning_rate: 2.5000e-04
# Epoch 41/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0182 - mae: 0.0346 - val_loss: 0.0193 - val_mae: 0.0493 - learning_rate: 2.5000e-04
# Epoch 42/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0178 - mae: 0.0322 - val_loss: 0.0212 - val_mae: 0.0645 - learning_rate: 2.5000e-04
# Epoch 43/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0178 - mae: 0.0333 - val_loss: 0.0193 - val_mae: 0.0512 - learning_rate: 2.5000e-04
# Epoch 44/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0174 - mae: 0.0310 - val_loss: 0.0191 - val_mae: 0.0505 - learning_rate: 2.5000e-04
# Epoch 45/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0174 - mae: 0.0318 - val_loss: 0.0195 - val_mae: 0.0548 - learning_rate: 2.5000e-04
# Epoch 46/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0172 - mae: 0.0322
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0172 - mae: 0.0322 - val_loss: 0.0186 - val_mae: 0.0481 - learning_rate: 2.5000e-04
# Epoch 47/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0170 - mae: 0.0311 - val_loss: 0.0189 - val_mae: 0.0517 - learning_rate: 1.2500e-04
# Epoch 48/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0171 - mae: 0.0323 - val_loss: 0.0187 - val_mae: 0.0510 - learning_rate: 1.2500e-04
# Epoch 49/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0171 - mae: 0.0331 - val_loss: 0.0188 - val_mae: 0.0521 - learning_rate: 1.2500e-04
# Epoch 50/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0169 - mae: 0.0316 - val_loss: 0.0185 - val_mae: 0.0502 - learning_rate: 1.2500e-04
# Epoch 51/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0168 - mae: 0.0314 - val_loss: 0.0183 - val_mae: 0.0494 - learning_rate: 1.2500e-04
# Epoch 52/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0169 - mae: 0.0329 - val_loss: 0.0186 - val_mae: 0.0525 - learning_rate: 1.2500e-04
# Epoch 53/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0165 - mae: 0.0307 - val_loss: 0.0182 - val_mae: 0.0490 - learning_rate: 1.2500e-04
# Epoch 54/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0165 - mae: 0.0315 - val_loss: 0.0180 - val_mae: 0.0486 - learning_rate: 1.2500e-04
# Epoch 55/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0167 - mae: 0.0329 - val_loss: 0.0176 - val_mae: 0.0455 - learning_rate: 1.2500e-04
# Epoch 56/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0164 - mae: 0.0315 - val_loss: 0.0175 - val_mae: 0.0453 - learning_rate: 1.2500e-04
# Epoch 57/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0163 - mae: 0.0315 - val_loss: 0.0181 - val_mae: 0.0512 - learning_rate: 1.2500e-04
# Epoch 58/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0163 - mae: 0.0328 - val_loss: 0.0175 - val_mae: 0.0464 - learning_rate: 1.2500e-04
# Epoch 59/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - loss: 0.0162 - mae: 0.0318 - val_loss: 0.0170 - val_mae: 0.0424 - learning_rate: 1.2500e-04
# Epoch 60/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - loss: 0.0161 - mae: 0.0312 - val_loss: 0.0173 - val_mae: 0.0467 - learning_rate: 1.2500e-04
# Epoch 61/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0160 - mae: 0.0308 - val_loss: 0.0171 - val_mae: 0.0451 - learning_rate: 1.2500e-04
# Epoch 62/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0159 - mae: 0.0313 - val_loss: 0.0172 - val_mae: 0.0472 - learning_rate: 1.2500e-04
# Epoch 63/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0160 - mae: 0.0328 - val_loss: 0.0167 - val_mae: 0.0431 - learning_rate: 1.2500e-04
# Epoch 64/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0157 - mae: 0.0306 - val_loss: 0.0166 - val_mae: 0.0427 - learning_rate: 1.2500e-04
# Epoch 65/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0156 - mae: 0.0308 - val_loss: 0.0169 - val_mae: 0.0465 - learning_rate: 1.2500e-04
# Epoch 66/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0157 - mae: 0.0322 - val_loss: 0.0164 - val_mae: 0.0425 - learning_rate: 1.2500e-04
# Epoch 67/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0154 - mae: 0.0306 - val_loss: 0.0162 - val_mae: 0.0409 - learning_rate: 1.2500e-04
# Epoch 68/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0155 - mae: 0.0317 - val_loss: 0.0161 - val_mae: 0.0412 - learning_rate: 1.2500e-04
# Epoch 69/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0153 - mae: 0.0306 - val_loss: 0.0160 - val_mae: 0.0412 - learning_rate: 1.2500e-04
# Epoch 70/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0153 - mae: 0.0314 - val_loss: 0.0162 - val_mae: 0.0440 - learning_rate: 1.2500e-04
# Epoch 71/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 0.0151 - mae: 0.0315 - val_loss: 0.0158 - val_mae: 0.0414 - learning_rate: 1.2500e-04
# Epoch 72/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0150 - mae: 0.0310 - val_loss: 0.0156 - val_mae: 0.0407 - learning_rate: 1.2500e-04
# Epoch 73/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0149 - mae: 0.0306 - val_loss: 0.0152 - val_mae: 0.0375 - learning_rate: 1.2500e-04
# Epoch 74/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 0.0146 - mae: 0.0290 - val_loss: 0.0159 - val_mae: 0.0456 - learning_rate: 1.2500e-04
# Epoch 75/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0148 - mae: 0.0323 - val_loss: 0.0151 - val_mae: 0.0380 - learning_rate: 1.2500e-04
# Epoch 76/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 0.0146 - mae: 0.0300 - val_loss: 0.0157 - val_mae: 0.0447 - learning_rate: 1.2500e-04
# Epoch 77/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - loss: 0.0146 - mae: 0.0307 - val_loss: 0.0153 - val_mae: 0.0422 - learning_rate: 1.2500e-04
# Epoch 78/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0143 - mae: 0.0301 - val_loss: 0.0148 - val_mae: 0.0381 - learning_rate: 1.2500e-04
# Epoch 79/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0142 - mae: 0.0299 - val_loss: 0.0148 - val_mae: 0.0385 - learning_rate: 1.2500e-04
# Epoch 80/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0141 - mae: 0.0297 - val_loss: 0.0146 - val_mae: 0.0378 - learning_rate: 1.2500e-04
# Epoch 81/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 0.0140 - mae: 0.0299 - val_loss: 0.0145 - val_mae: 0.0384 - learning_rate: 1.2500e-04
# Epoch 82/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0139 - mae: 0.0292 - val_loss: 0.0143 - val_mae: 0.0367 - learning_rate: 1.2500e-04
# Epoch 83/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 0.0139 - mae: 0.0303 - val_loss: 0.0145 - val_mae: 0.0403 - learning_rate: 1.2500e-04
# Epoch 84/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 0.0139 - mae: 0.0310 - val_loss: 0.0138 - val_mae: 0.0331 - learning_rate: 1.2500e-04
# Epoch 85/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0136 - mae: 0.0296 - val_loss: 0.0148 - val_mae: 0.0448 - learning_rate: 1.2500e-04
# Epoch 86/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - loss: 0.0135 - mae: 0.0304 - val_loss: 0.0136 - val_mae: 0.0326 - learning_rate: 1.2500e-04
# Epoch 87/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - loss: 0.0133 - mae: 0.0292 - val_loss: 0.0142 - val_mae: 0.0409 - learning_rate: 1.2500e-04
# Epoch 88/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 0.0133 - mae: 0.0298 - val_loss: 0.0134 - val_mae: 0.0329 - learning_rate: 1.2500e-04
# Epoch 89/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - loss: 0.0131 - mae: 0.0295 - val_loss: 0.0137 - val_mae: 0.0387 - learning_rate: 1.2500e-04
# Epoch 90/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 0.0131 - mae: 0.0295 - val_loss: 0.0134 - val_mae: 0.0361 - learning_rate: 1.2500e-04
# Epoch 91/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 0.0130 - mae: 0.0295 - val_loss: 0.0140 - val_mae: 0.0435 - learning_rate: 1.2500e-04
# Epoch 92/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0129 - mae: 0.0305 - val_loss: 0.0130 - val_mae: 0.0335 - learning_rate: 1.2500e-04
# Epoch 93/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 0.0129 - mae: 0.0311 - val_loss: 0.0131 - val_mae: 0.0367 - learning_rate: 1.2500e-04
# Epoch 94/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0127 - mae: 0.0300 - val_loss: 0.0129 - val_mae: 0.0355 - learning_rate: 1.2500e-04
# Epoch 95/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 0.0125 - mae: 0.0303 - val_loss: 0.0133 - val_mae: 0.0418 - learning_rate: 1.2500e-04
# Epoch 96/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0126 - mae: 0.0321 - val_loss: 0.0134 - val_mae: 0.0432 - learning_rate: 1.2500e-04
# Epoch 97/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0123 - mae: 0.0301 - val_loss: 0.0125 - val_mae: 0.0338 - learning_rate: 1.2500e-04
# Epoch 98/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0123 - mae: 0.0304 - val_loss: 0.0122 - val_mae: 0.0308 - learning_rate: 1.2500e-04
# Epoch 99/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - loss: 0.0124 - mae: 0.0325 - val_loss: 0.0120 - val_mae: 0.0303 - learning_rate: 1.2500e-04
# Epoch 100/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0120 - mae: 0.0305 - val_loss: 0.0127 - val_mae: 0.0409 - learning_rate: 1.2500e-04
# Epoch 101/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 0.0122 - mae: 0.0350 - val_loss: 0.0127 - val_mae: 0.0417 - learning_rate: 1.2500e-04
# Epoch 102/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0121 - mae: 0.0344 - val_loss: 0.0122 - val_mae: 0.0370 - learning_rate: 1.2500e-04
# Epoch 103/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0120 - mae: 0.0331 - val_loss: 0.0117 - val_mae: 0.0315 - learning_rate: 1.2500e-04
# Epoch 104/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - loss: 0.0122 - mae: 0.0362 - val_loss: 0.0114 - val_mae: 0.0285 - learning_rate: 1.2500e-04
# Epoch 105/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - loss: 0.0117 - mae: 0.0327 - val_loss: 0.0123 - val_mae: 0.0423 - learning_rate: 1.2500e-04
# Epoch 106/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0119 - mae: 0.0364 - val_loss: 0.0124 - val_mae: 0.0442 - learning_rate: 1.2500e-04
# Epoch 107/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0120 - mae: 0.0394 - val_loss: 0.0120 - val_mae: 0.0408 - learning_rate: 1.2500e-04
# Epoch 108/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 0.0114 - mae: 0.0326 - val_loss: 0.0112 - val_mae: 0.0326 - learning_rate: 1.2500e-04
# Epoch 109/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0127 - mae: 0.0456 - val_loss: 0.0113 - val_mae: 0.0330 - learning_rate: 1.2500e-04
# Epoch 110/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0127 - mae: 0.0468 - val_loss: 0.0108 - val_mae: 0.0304 - learning_rate: 1.2500e-04
# Epoch 111/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0117 - mae: 0.0379 - val_loss: 0.0144 - val_mae: 0.0651 - learning_rate: 1.2500e-04
# Epoch 112/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0135 - mae: 0.0555 - val_loss: 0.0112 - val_mae: 0.0382 - learning_rate: 1.2500e-04
# Epoch 113/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0108 - mae: 0.0321 - val_loss: 0.0112 - val_mae: 0.0376 - learning_rate: 1.2500e-04
# Epoch 114/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0126 - mae: 0.0478 - val_loss: 0.0106 - val_mae: 0.0313 - learning_rate: 1.2500e-04
# Epoch 115/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0109 - mae: 0.0345 - val_loss: 0.0116 - val_mae: 0.0466 - learning_rate: 1.2500e-04
# Epoch 116/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0109 - mae: 0.0356 - val_loss: 0.0112 - val_mae: 0.0420 - learning_rate: 1.2500e-04
# Epoch 117/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0104 - mae: 0.0331 - val_loss: 0.0104 - val_mae: 0.0345 - learning_rate: 1.2500e-04
# Epoch 118/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0103 - mae: 0.0316 - val_loss: 0.0101 - val_mae: 0.0307 - learning_rate: 1.2500e-04
# Epoch 119/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0103 - mae: 0.0321 - val_loss: 0.0099 - val_mae: 0.0302 - learning_rate: 1.2500e-04
# Epoch 120/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0100 - mae: 0.0301 - val_loss: 0.0101 - val_mae: 0.0350 - learning_rate: 1.2500e-04
# Epoch 121/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0100 - mae: 0.0330 - val_loss: 0.0110 - val_mae: 0.0456 - learning_rate: 1.2500e-04
# Epoch 122/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0100 - mae: 0.0329 - val_loss: 0.0098 - val_mae: 0.0324 - learning_rate: 1.2500e-04
# Epoch 123/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0100 - mae: 0.0325 - val_loss: 0.0096 - val_mae: 0.0307 - learning_rate: 1.2500e-04
# Epoch 124/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0101 - mae: 0.0350 - val_loss: 0.0094 - val_mae: 0.0280 - learning_rate: 1.2500e-04
# Epoch 125/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0096 - mae: 0.0311 - val_loss: 0.0100 - val_mae: 0.0388 - learning_rate: 1.2500e-04
# Epoch 126/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0099 - mae: 0.0359 - val_loss: 0.0102 - val_mae: 0.0420 - learning_rate: 1.2500e-04
# Epoch 127/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0098 - mae: 0.0366 - val_loss: 0.0103 - val_mae: 0.0433 - learning_rate: 1.2500e-04
# Epoch 128/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0095 - mae: 0.0328 - val_loss: 0.0092 - val_mae: 0.0304 - learning_rate: 1.2500e-04
# Epoch 129/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0104 - mae: 0.0418 - val_loss: 0.0089 - val_mae: 0.0278 - learning_rate: 1.2500e-04
# Epoch 130/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0095 - mae: 0.0347 - val_loss: 0.0090 - val_mae: 0.0311 - learning_rate: 1.2500e-04
# Epoch 131/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0092 - mae: 0.0337 - val_loss: 0.0101 - val_mae: 0.0457 - learning_rate: 1.2500e-04
# Epoch 132/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0099 - mae: 0.0415 - val_loss: 0.0105 - val_mae: 0.0493 - learning_rate: 1.2500e-04
# Epoch 133/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0092 - mae: 0.0345 - val_loss: 0.0088 - val_mae: 0.0321 - learning_rate: 1.2500e-04
# Epoch 134/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 0.0103 - mae: 0.0450 - val_loss: 0.0087 - val_mae: 0.0297 - learning_rate: 1.2500e-04
# Epoch 135/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0096 - mae: 0.0407 - val_loss: 0.0086 - val_mae: 0.0329 - learning_rate: 1.2500e-04
# Epoch 136/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0094 - mae: 0.0394 - val_loss: 0.0100 - val_mae: 0.0490 - learning_rate: 1.2500e-04
# Epoch 137/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0096 - mae: 0.0431 - val_loss: 0.0097 - val_mae: 0.0459 - learning_rate: 1.2500e-04
# Epoch 138/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0088 - mae: 0.0356 - val_loss: 0.0083 - val_mae: 0.0295 - learning_rate: 1.2500e-04
# Epoch 139/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0105 - mae: 0.0495 - val_loss: 0.0081 - val_mae: 0.0270 - learning_rate: 1.2500e-04
# Epoch 140/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0086 - mae: 0.0343 - val_loss: 0.0094 - val_mae: 0.0467 - learning_rate: 1.2500e-04
# Epoch 141/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0093 - mae: 0.0426 - val_loss: 0.0092 - val_mae: 0.0443 - learning_rate: 1.2500e-04
# Epoch 142/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0084 - mae: 0.0346 - val_loss: 0.0086 - val_mae: 0.0384 - learning_rate: 1.2500e-04
# Epoch 143/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0084 - mae: 0.0349 - val_loss: 0.0078 - val_mae: 0.0294 - learning_rate: 1.2500e-04
# Epoch 144/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0086 - mae: 0.0372 - val_loss: 0.0076 - val_mae: 0.0268 - learning_rate: 1.2500e-04
# Epoch 145/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0078 - mae: 0.0291 - val_loss: 0.0086 - val_mae: 0.0425 - learning_rate: 1.2500e-04
# Epoch 146/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0081 - mae: 0.0351 - val_loss: 0.0079 - val_mae: 0.0353 - learning_rate: 1.2500e-04
# Epoch 147/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - loss: 0.0078 - mae: 0.0322 - val_loss: 0.0083 - val_mae: 0.0402 - learning_rate: 1.2500e-04
# Epoch 148/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0081 - mae: 0.0344 - val_loss: 0.0076 - val_mae: 0.0295 - learning_rate: 1.2500e-04
# Epoch 149/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0079 - mae: 0.0342 - val_loss: 0.0079 - val_mae: 0.0369 - learning_rate: 1.2500e-04
# Epoch 150/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 0.0075 - mae: 0.0299 - val_loss: 0.0073 - val_mae: 0.0305 - learning_rate: 1.2500e-04
# Epoch 151/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0080 - mae: 0.0368 - val_loss: 0.0097 - val_mae: 0.0552 - learning_rate: 1.2500e-04
# Epoch 152/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0076 - mae: 0.0331 - val_loss: 0.0073 - val_mae: 0.0305 - learning_rate: 1.2500e-04
# Epoch 153/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0078 - mae: 0.0369 - val_loss: 0.0071 - val_mae: 0.0277 - learning_rate: 1.2500e-04
# Epoch 154/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0079 - mae: 0.0373 - val_loss: 0.0070 - val_mae: 0.0287 - learning_rate: 1.2500e-04
# Epoch 155/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0072 - mae: 0.0308 - val_loss: 0.0081 - val_mae: 0.0444 - learning_rate: 1.2500e-04
# Epoch 156/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0078 - mae: 0.0386 - val_loss: 0.0077 - val_mae: 0.0400 - learning_rate: 1.2500e-04
# Epoch 157/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0071 - mae: 0.0317 - val_loss: 0.0077 - val_mae: 0.0402 - learning_rate: 1.2500e-04
# Epoch 158/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - loss: 0.0075 - mae: 0.0351 - val_loss: 0.0072 - val_mae: 0.0329 - learning_rate: 1.2500e-04
# Epoch 159/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0076 - mae: 0.0385 - val_loss: 0.0069 - val_mae: 0.0333 - learning_rate: 1.2500e-04
# Epoch 160/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0068 - mae: 0.0305 - val_loss: 0.0072 - val_mae: 0.0375 - learning_rate: 1.2500e-04
# Epoch 161/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0076 - mae: 0.0400 - val_loss: 0.0083 - val_mae: 0.0494 - learning_rate: 1.2500e-04
# Epoch 162/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0069 - mae: 0.0346 - val_loss: 0.0069 - val_mae: 0.0354 - learning_rate: 1.2500e-04
# Epoch 163/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0073 - mae: 0.0367 - val_loss: 0.0067 - val_mae: 0.0308 - learning_rate: 1.2500e-04
# Epoch 164/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0077 - mae: 0.0415 - val_loss: 0.0064 - val_mae: 0.0275 - learning_rate: 1.2500e-04
# Epoch 165/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0067 - mae: 0.0329 - val_loss: 0.0072 - val_mae: 0.0413 - learning_rate: 1.2500e-04
# Epoch 166/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0074 - mae: 0.0408 - val_loss: 0.0071 - val_mae: 0.0406 - learning_rate: 1.2500e-04
# Epoch 167/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0069 - mae: 0.0365 - val_loss: 0.0073 - val_mae: 0.0422 - learning_rate: 1.2500e-04
# Epoch 168/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0067 - mae: 0.0342 - val_loss: 0.0064 - val_mae: 0.0306 - learning_rate: 1.2500e-04
# Epoch 169/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0073 - mae: 0.0406 - val_loss: 0.0060 - val_mae: 0.0274 - learning_rate: 1.2500e-04
# Epoch 170/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0064 - mae: 0.0316 - val_loss: 0.0066 - val_mae: 0.0369 - learning_rate: 1.2500e-04
# Epoch 171/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0071 - mae: 0.0399 - val_loss: 0.0075 - val_mae: 0.0472 - learning_rate: 1.2500e-04
# Epoch 172/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 0.0066 - mae: 0.0371 - val_loss: 0.0065 - val_mae: 0.0361 - learning_rate: 1.2500e-04
# Epoch 173/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0066 - mae: 0.0349 - val_loss: 0.0060 - val_mae: 0.0290 - learning_rate: 1.2500e-04
# Epoch 174/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0068 - mae: 0.0388 - val_loss: 0.0060 - val_mae: 0.0290 - learning_rate: 1.2500e-04
# Epoch 175/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0062 - mae: 0.0330 - val_loss: 0.0066 - val_mae: 0.0404 - learning_rate: 1.2500e-04
# Epoch 176/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0064 - mae: 0.0365 - val_loss: 0.0059 - val_mae: 0.0315 - learning_rate: 1.2500e-04
# Epoch 177/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0061 - mae: 0.0342 - val_loss: 0.0075 - val_mae: 0.0501 - learning_rate: 1.2500e-04
# Epoch 178/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0059 - mae: 0.0316 - val_loss: 0.0061 - val_mae: 0.0327 - learning_rate: 1.2500e-04
# Epoch 179/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0062 - mae: 0.0344 - val_loss: 0.0059 - val_mae: 0.0333 - learning_rate: 1.2500e-04
# Epoch 180/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0057 - mae: 0.0292 - val_loss: 0.0055 - val_mae: 0.0290 - learning_rate: 1.2500e-04
# Epoch 181/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0062 - mae: 0.0376 - val_loss: 0.0079 - val_mae: 0.0552 - learning_rate: 1.2500e-04
# Epoch 182/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0060 - mae: 0.0354 - val_loss: 0.0057 - val_mae: 0.0326 - learning_rate: 1.2500e-04
# Epoch 183/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 0.0060 - mae: 0.0353 - val_loss: 0.0054 - val_mae: 0.0277 - learning_rate: 1.2500e-04
# Epoch 184/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0063 - mae: 0.0370 - val_loss: 0.0057 - val_mae: 0.0317 - learning_rate: 1.2500e-04
# Epoch 185/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0057 - mae: 0.0321 - val_loss: 0.0066 - val_mae: 0.0460 - learning_rate: 1.2500e-04
# Epoch 186/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0061 - mae: 0.0388 - val_loss: 0.0057 - val_mae: 0.0346 - learning_rate: 1.2500e-04
# Epoch 187/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0060 - mae: 0.0381 - val_loss: 0.0074 - val_mae: 0.0520 - learning_rate: 1.2500e-04
# Epoch 188/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0058 - mae: 0.0347 - val_loss: 0.0060 - val_mae: 0.0366 - learning_rate: 1.2500e-04
# Epoch 189/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0064 - mae: 0.0422 - val_loss: 0.0052 - val_mae: 0.0298 - learning_rate: 1.2500e-04
# Epoch 190/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0054 - mae: 0.0323 - val_loss: 0.0051 - val_mae: 0.0274 - learning_rate: 1.2500e-04
# Epoch 191/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0062 - mae: 0.0412 - val_loss: 0.0085 - val_mae: 0.0624 - learning_rate: 1.2500e-04
# Epoch 192/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0061 - mae: 0.0405 - val_loss: 0.0052 - val_mae: 0.0302 - learning_rate: 1.2500e-04
# Epoch 193/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0055 - mae: 0.0330 - val_loss: 0.0057 - val_mae: 0.0391 - learning_rate: 1.2500e-04
# Epoch 194/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0063 - mae: 0.0410 - val_loss: 0.0062 - val_mae: 0.0423 - learning_rate: 1.2500e-04
# Epoch 195/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0056 - mae: 0.0351 - val_loss: 0.0089 - val_mae: 0.0669 - learning_rate: 1.2500e-04
# Epoch 196/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0057 - mae: 0.0379 - val_loss: 0.0050 - val_mae: 0.0300 - learning_rate: 1.2500e-04
# Epoch 197/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0051 - mae: 0.0313
# Epoch 197: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0051 - mae: 0.0314 - val_loss: 0.0074 - val_mae: 0.0551 - learning_rate: 1.2500e-04
# Epoch 198/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0052 - mae: 0.0323 - val_loss: 0.0056 - val_mae: 0.0394 - learning_rate: 6.2500e-05
# Epoch 199/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0049 - mae: 0.0290 - val_loss: 0.0056 - val_mae: 0.0394 - learning_rate: 6.2500e-05
# Epoch 200/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 0.0048 - mae: 0.0292 - val_loss: 0.0051 - val_mae: 0.0333 - learning_rate: 6.2500e-05
# Epoch 201/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0047 - mae: 0.0278 - val_loss: 0.0055 - val_mae: 0.0383 - learning_rate: 6.2500e-05
# Epoch 202/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0047 - mae: 0.0284 - val_loss: 0.0054 - val_mae: 0.0377 - learning_rate: 6.2500e-05
# Epoch 203/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 0.0047 - mae: 0.0279 - val_loss: 0.0054 - val_mae: 0.0379 - learning_rate: 6.2500e-05
# Epoch 204/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0047 - mae: 0.0283
# Epoch 204: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0047 - mae: 0.0283 - val_loss: 0.0052 - val_mae: 0.0352 - learning_rate: 6.2500e-05
# Epoch 205/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - loss: 0.0046 - mae: 0.0280 - val_loss: 0.0052 - val_mae: 0.0361 - learning_rate: 3.1250e-05
# Epoch 206/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 231ms/step - loss: 0.0047 - mae: 0.0285 - val_loss: 0.0051 - val_mae: 0.0350 - learning_rate: 3.1250e-05
# Epoch 207/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.0047 - mae: 0.0281 - val_loss: 0.0051 - val_mae: 0.0350 - learning_rate: 3.1250e-05
# Epoch 208/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - loss: 0.0046 - mae: 0.0276 - val_loss: 0.0051 - val_mae: 0.0353 - learning_rate: 3.1250e-05
# Epoch 209/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 0.0045 - mae: 0.0274 - val_loss: 0.0050 - val_mae: 0.0340 - learning_rate: 3.1250e-05
# Epoch 210/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - loss: 0.0045 - mae: 0.0264 - val_loss: 0.0050 - val_mae: 0.0344 - learning_rate: 3.1250e-05
# Epoch 211/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0046 - mae: 0.0276
# Epoch 211: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 0.0046 - mae: 0.0277 - val_loss: 0.0052 - val_mae: 0.0369 - learning_rate: 3.1250e-05
# Epoch 212/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - loss: 0.0046 - mae: 0.0285 - val_loss: 0.0048 - val_mae: 0.0312 - learning_rate: 1.5625e-05
# Epoch 213/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - loss: 0.0045 - mae: 0.0269 - val_loss: 0.0048 - val_mae: 0.0316 - learning_rate: 1.5625e-05
# Epoch 214/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0045 - mae: 0.0267 - val_loss: 0.0048 - val_mae: 0.0311 - learning_rate: 1.5625e-05
# Epoch 215/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0045 - mae: 0.0265 - val_loss: 0.0049 - val_mae: 0.0326 - learning_rate: 1.5625e-05
# Epoch 216/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - loss: 0.0045 - mae: 0.0270 - val_loss: 0.0049 - val_mae: 0.0324 - learning_rate: 1.5625e-05
# Epoch 217/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 0.0044 - mae: 0.0269 - val_loss: 0.0049 - val_mae: 0.0324 - learning_rate: 1.5625e-05
# Epoch 218/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 0.0045 - mae: 0.0268 - val_loss: 0.0049 - val_mae: 0.0331 - learning_rate: 1.5625e-05
# Epoch 219/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0045 - mae: 0.0267
# Epoch 219: ReduceLROnPlateau reducing learning rate to 1e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 0.0045 - mae: 0.0267 - val_loss: 0.0050 - val_mae: 0.0342 - learning_rate: 1.5625e-05
# Epoch 220/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0045 - mae: 0.0272 - val_loss: 0.0048 - val_mae: 0.0322 - learning_rate: 1.0000e-05
# Epoch 221/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 0.0045 - mae: 0.0267 - val_loss: 0.0049 - val_mae: 0.0331 - learning_rate: 1.0000e-05
# Epoch 222/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - loss: 0.0044 - mae: 0.0257 - val_loss: 0.0048 - val_mae: 0.0324 - learning_rate: 1.0000e-05
# Epoch 223/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.0044 - mae: 0.0263 - val_loss: 0.0049 - val_mae: 0.0334 - learning_rate: 1.0000e-05
# Epoch 224/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - loss: 0.0045 - mae: 0.0267 - val_loss: 0.0049 - val_mae: 0.0330 - learning_rate: 1.0000e-05
# Epoch 225/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0044 - mae: 0.0265 - val_loss: 0.0049 - val_mae: 0.0330 - learning_rate: 1.0000e-05
# Epoch 226/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0045 - mae: 0.0272 - val_loss: 0.0048 - val_mae: 0.0323 - learning_rate: 1.0000e-05
# Epoch 227/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0044 - mae: 0.0262 - val_loss: 0.0048 - val_mae: 0.0327 - learning_rate: 1.0000e-05
# Epoch 228/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 0.0045 - mae: 0.0267 - val_loss: 0.0048 - val_mae: 0.0324 - learning_rate: 1.0000e-05
# Epoch 229/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - loss: 0.0044 - mae: 0.0266 - val_loss: 0.0049 - val_mae: 0.0329 - learning_rate: 1.0000e-05
# Epoch 230/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0044 - mae: 0.0262 - val_loss: 0.0049 - val_mae: 0.0331 - learning_rate: 1.0000e-05
# Epoch 231/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0044 - mae: 0.0266 - val_loss: 0.0049 - val_mae: 0.0332 - learning_rate: 1.0000e-05
# Epoch 232/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 0.0044 - mae: 0.0263 - val_loss: 0.0048 - val_mae: 0.0329 - learning_rate: 1.0000e-05
# Epoch 233/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 0.0043 - mae: 0.0259 - val_loss: 0.0049 - val_mae: 0.0331 - learning_rate: 1.0000e-05
# Epoch 234/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - loss: 0.0043 - mae: 0.0260 - val_loss: 0.0049 - val_mae: 0.0337 - learning_rate: 1.0000e-05
# Epoch 234: early stopping
# Restoring model weights from the end of the best epoch: 214.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
#
# Evaluation metrics:
# MAE: 0.001961
# MSE: 0.000011

# %%
# Plot training and validation loss to visualize training progress
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
